# %% [markdown]
# 04_eda.ipynb
#
# 1. Shape
# 2. Info
# 3. Missing Values
# 4. Describe
# 5. Distributionen
# 6. Top Routes
# 7. Year-over-Year Development
# 8. Passengers vs Cargo
# 9. Correlationen
# 10. Erste Erkenntnisse
